# %% [markdown]
# # 03 - Entrenamiento visual
#
# Ajustar un modelo preentrenado para cinco clases.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Baseline
# 2. Fine-tuning
# 3. Métricas
# 4. Checkpoint

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
