# %% [markdown]
# # 01 - Adquisición y auditoría
#
# Validar estructura, integridad y distribución del dataset.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Registrar fuente
# 2. Verificar clases
# 3. Auditar imágenes
# 4. Revisar resultados

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
