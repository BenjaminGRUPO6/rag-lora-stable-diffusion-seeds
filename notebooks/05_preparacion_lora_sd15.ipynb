# %% [markdown]
# # 05 - Preparación del dataset LoRA
#
# **Objetivo:** Crear un subconjunto de clases minoritarias con captions coherentes.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Seleccionar imágenes verificadas.
# 2. Copiar imágenes a ImageFolder.
# 3. Generar metadata.jsonl.
# 4. Revisar captions y trigger word.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
