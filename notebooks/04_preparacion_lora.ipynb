# %% [markdown]
# # 04 - Preparación de LoRA
#
# Crear captions y metadata para Stable Diffusion 1.5.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Seleccionar imágenes
# 2. Generar captions
# 3. Validar metadata
# 4. Crear muestras

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
