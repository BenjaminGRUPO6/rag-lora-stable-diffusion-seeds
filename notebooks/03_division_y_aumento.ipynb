# %% [markdown]
# # 03 - División y aumento
#
# **Objetivo:** Separar train/validation/test y aplicar aumento únicamente a train.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Realizar división estratificada.
# 2. Aplicar transformaciones suaves.
# 3. Mantener original_id para evitar fuga de datos.
# 4. Comparar balance antes y después.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
