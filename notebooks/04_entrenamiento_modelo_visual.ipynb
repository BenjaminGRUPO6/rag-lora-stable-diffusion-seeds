# %% [markdown]
# # 04 - Entrenamiento del modelo visual
#
# **Objetivo:** Ajustar un modelo preentrenado para clasificar daños visibles.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Crear DataLoaders.
# 2. Entrenar ResNet18 como línea base.
# 3. Evaluar F1 por clase y matriz de confusión.
# 4. Guardar el mejor checkpoint.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
