# %% [markdown]
# # 02 - Limpieza y etiquetado
#
# **Objetivo:** Construir metadatos confiables y etiquetas verificadas.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Revisar duplicados y archivos inválidos.
# 2. Asignar etiqueta principal y subetiqueta.
# 3. Registrar procedencia y verificación.
# 4. Exportar images.csv.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
