# %% [markdown]
# # 00 - Configuración del entorno
#
# Verificar Python, GPU, rutas y dependencias.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Cargar configuraciones
# 2. Comprobar versiones
# 3. Registrar hardware y semilla

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
