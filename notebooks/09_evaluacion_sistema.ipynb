# %% [markdown]
# # 09 - Evaluación final
#
# **Objetivo:** Comparar líneas base y medir el sistema completo.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Comparar clasificador sin y con datos sintéticos.
# 2. Evaluar fidelidad de imágenes LoRA.
# 3. Evaluar recuperación documental.
# 4. Medir latencia y revisión humana.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
