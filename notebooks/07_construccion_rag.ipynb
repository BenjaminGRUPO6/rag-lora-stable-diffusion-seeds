# %% [markdown]
# # 07 - Construcción del RAG
#
# **Objetivo:** Indexar fuentes técnicas y comprobar la recuperación.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Validar procedencia de documentos.
# 2. Extraer texto y crear chunks.
# 3. Generar embeddings multilingües.
# 4. Construir FAISS.
# 5. Evaluar Precision@k y MRR.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
