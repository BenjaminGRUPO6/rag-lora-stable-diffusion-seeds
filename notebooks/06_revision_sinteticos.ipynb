# %% [markdown]
# # 06 - Revisión de sintéticos
#
# Evaluar y aprobar manualmente las imágenes generadas.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Generar lotes
# 2. Registrar aceptación
# 3. Descartar defectos
# 4. Crear dataset comparativo

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
