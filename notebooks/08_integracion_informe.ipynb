# %% [markdown]
# # 08 - Integración e informe
#
# **Objetivo:** Combinar clasificación, recuperación y generación de informe con fuentes.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Ejecutar inferencia visual.
# 2. Construir consulta del RAG.
# 3. Recuperar fuentes.
# 4. Generar informe preliminar y limitaciones.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
