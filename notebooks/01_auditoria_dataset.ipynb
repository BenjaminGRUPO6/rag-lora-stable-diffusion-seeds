# %% [markdown]
# # 01 - Auditoría del dataset
#
# **Objetivo:** Conocer el estado real de las imágenes antes de modificarlas.
#
# Este notebook es una guía ejecutable. Complete las rutas y parámetros antes de ejecutar.

# %% [markdown]
# ## Pasos
# 1. Configurar la ruta del dataset.
# 2. Detectar archivos corruptos y duplicados.
# 3. Obtener distribución por clases y resolución.
# 4. Guardar el informe de auditoría.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)

# %% [markdown]
# ## Registro de resultados
# - Anote parámetros, tiempos, métricas y errores.
# - Guarde únicamente resultados seleccionados en `results/`.
# - No suba el dataset completo ni checkpoints grandes a GitHub.
