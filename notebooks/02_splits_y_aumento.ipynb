# %% [markdown]
# # 02 - Splits y aumento
#
# Crear divisiones reproducibles y aumento solo en train.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Revisar duplicados
# 2. Split estratificado
# 3. Aumento convencional
# 4. Guardar manifiestos

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
