# %% [markdown]
# # 05 - Entrenamiento SD 1.5 + LoRA
#
# Ejecutar prueba y entrenamiento en Google Colab.
#
# > Este notebook es una guía reproducible. Complete cada bloque en la rama correspondiente y registre parámetros, resultados y conclusiones.

# %% [markdown]
# ## Pasos previstos
# 1. Configurar GPU
# 2. Prueba 100 pasos
# 3. Corrida 800 pasos
# 4. Guardar pesos y validaciones

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
